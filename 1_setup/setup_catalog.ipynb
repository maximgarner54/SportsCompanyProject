-- %%
%sql
CREATE CATALOG IF NOT EXISTS SportsProject;
USE CATALOG SportsProject;

-- %%
%sql
CREATE SCHEMA IF NOT EXISTS SportsProject.gold;
CREATE SCHEMA IF NOT EXISTS SportsProject.silver;
CREATE SCHEMA IF NOT EXISTS SportsProject.bronze;
